# %% [markdown]
# ## 数组处理

# %%
import seaborn as sns  # Powerful plots

anscombe = sns.load_dataset("anscombe")
anscombe.groupby("dataset").describe().iloc[:,[1,2,9,10]]
# Out:
#            x                   y
#         mean       std      mean       std
# dataset
# I        9.0  3.316625  7.500909  2.031568
# II       9.0  3.316625  7.500909  2.031657
# III      9.0  3.316625  7.500000  2.030424
# IV       9.0  3.316625  7.500909  2.030579

# %%
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import numpy as np

ans = anscombe
ans['index'] = np.tile(np.arange(12)[1:],4)
#生成的方法还有
#np.arange(11).repeat(4).reshape(11,4).ravel('F')
#np.zeros((11,4))+np.arange(11).reshape(11,1)
ans
# Out:
# xy dataset     x      y  index
# 0        I  10.0   8.04      1
# 1        I   8.0   6.95      2
# 2        I  13.0   7.58      3
# 3        I   9.0   8.81      4
# 4        I  11.0   8.33      5
# 5        I  14.0   9.96      6
# 6        I   6.0   7.24      7
# 7        I   4.0   4.26      8
# 8        I  12.0  10.84      9
# 9        I   7.0   4.82     10
# 10       I   5.0   5.68     11
# 11      II  10.0   9.14      1
# 12      II   8.0   8.14      2
# 13      II  13.0   8.74      3
# 14      II   9.0   8.77      4
# 15      II  11.0   9.26      5
# 16      II  14.0   8.10      6
# 17      II   6.0   6.13      7
# 18      II   4.0   3.10      8
# 19      II  12.0   9.13      9
# 20      II   7.0   7.26     10
# 21      II   5.0   4.74     11
# 22     III  10.0   7.46      1
# 23     III   8.0   6.77      2
# 24     III  13.0  12.74      3
# 25     III   9.0   7.11      4
# 26     III  11.0   7.81      5
# 27     III  14.0   8.84      6
# 28     III   6.0   6.08      7
# ...

# %%
ans.pivot('index','dataset')
# Out:
#             x                        y
# dataset     I    II   III    IV      I    II    III     IV
# index
# 1        10.0  10.0  10.0   8.0   8.04  9.14   7.46   6.58
# 2         8.0   8.0   8.0   8.0   6.95  8.14   6.77   5.76
# 3        13.0  13.0  13.0   8.0   7.58  8.74  12.74   7.71
# 4         9.0   9.0   9.0   8.0   8.81  8.77   7.11   8.84
# 5        11.0  11.0  11.0   8.0   8.33  9.26   7.81   8.47
# 6        14.0  14.0  14.0   8.0   9.96  8.10   8.84   7.04
# 7         6.0   6.0   6.0   8.0   7.24  6.13   6.08   5.25
# 8         4.0   4.0   4.0  19.0   4.26  3.10   5.39  12.50
# 9        12.0  12.0  12.0   8.0  10.84  9.13   8.15   5.56
# 10        7.0   7.0   7.0   8.0   4.82  7.26   6.42   7.91
# 11        5.0   5.0   5.0   8.0   5.68  4.74   5.73   6.89

# %%
ans.columns.names = ['xy']
ans.pivot('index','dataset').swaplevel(0,1,axis=1).sort_index(level='dataset',axis=1)
# Out:
# dataset     I           II         III           IV
# xy          x      y     x     y     x      y     x      y
# index
# 1        10.0   8.04  10.0  9.14  10.0   7.46   8.0   6.58
# 2         8.0   6.95   8.0  8.14   8.0   6.77   8.0   5.76
# 3        13.0   7.58  13.0  8.74  13.0  12.74   8.0   7.71
# 4         9.0   8.81   9.0  8.77   9.0   7.11   8.0   8.84
# 5        11.0   8.33  11.0  9.26  11.0   7.81   8.0   8.47
# 6        14.0   9.96  14.0  8.10  14.0   8.84   8.0   7.04
# 7         6.0   7.24   6.0  6.13   6.0   6.08   8.0   5.25
# 8         4.0   4.26   4.0  3.10   4.0   5.39  19.0  12.50
# 9        12.0  10.84  12.0  9.13  12.0   8.15   8.0   5.56
# 10        7.0   4.82   7.0  7.26   7.0   6.42   8.0   7.91
# 11        5.0   5.68   5.0  4.74   5.0   5.73   8.0   6.89

# %%
np.array(aa)
# Out:
# array([[ 10.  ,   8.04,  10.  ,   9.14,  10.  ,   7.46,   8.  ,   6.58],
#        [  8.  ,   6.95,   8.  ,   8.14,   8.  ,   6.77,   8.  ,   5.76],
#        [ 13.  ,   7.58,  13.  ,   8.74,  13.  ,  12.74,   8.  ,   7.71],
#        [  9.  ,   8.81,   9.  ,   8.77,   9.  ,   7.11,   8.  ,   8.84],
#        [ 11.  ,   8.33,  11.  ,   9.26,  11.  ,   7.81,   8.  ,   8.47],
#        [ 14.  ,   9.96,  14.  ,   8.1 ,  14.  ,   8.84,   8.  ,   7.04],
#        [  6.  ,   7.24,   6.  ,   6.13,   6.  ,   6.08,   8.  ,   5.25],
#        [  4.  ,   4.26,   4.  ,   3.1 ,   4.  ,   5.39,  19.  ,  12.5 ],
#        [ 12.  ,  10.84,  12.  ,   9.13,  12.  ,   8.15,   8.  ,   5.56],
#        [  7.  ,   4.82,   7.  ,   7.26,   7.  ,   6.42,   8.  ,   7.91],
#        [  5.  ,   5.68,   5.  ,   4.74,   5.  ,   5.73,   8.  ,   6.89]])

# %%
anscombe.dataset.unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
# %pylab inline

import numpy as np

i   = np.array([
    [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0],
    [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
])

ii  = np.array([
    [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0],
    [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
])

iii = np.array([
    [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0],
    [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
])

iv  = np.array([
    [8.0, 8.0, 8.0, 8.0, 8.0, 8.0, 8.0, 19.0, 8.0, 8.0, 8.0],
    [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]
])

def make_plot(a, b, c, d):
    fig, ((axa, axb), (axc, axd)) =  plt.subplots(2, 2, sharex='col', sharey='row')
    for arr, ax in ((a, axa), (b, axb), (c, axc), (d, axd)):
        x = arr[0]
        y = arr[1]

        ax.scatter(x, y, c='g')
        m,b = np.polyfit(x, y, 1)
        X = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
        ax.plot(X, m*X+b, '-')
    plt.show()

make_plot(i, ii, iii, iv)
# Out:
# Populating the interactive namespace from numpy and matplotlib
